# %% [markdown]
# <h3>數值資料型態</h3>

# %%
1+True

# %%
False*4
# Out:
# 0

# %%
# True is 1
1+True
# Out:
# 2

# %%
888.0**999
# Out:
# ---------------------------------------------------------------------------
# OverflowError                             Traceback (most recent call last)
# <ipython-input-5-0e57fcab240c> in <module>
# ----> 1 888.0**999
#
# OverflowError: (34, 'Result too large')

# %%
a=2.5e2
b=4
c=a*b
print(c)
# Out:
# 1000.0

# %%
99999**999
# Out:
# ...

# %%
ob011
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-15-847ff046473b> in <module>
# ----> 1 ob011
#
# NameError: name 'ob011' is not defined

# %%
0b011
# Out:
# 3

# %%
0b1010
# Out:
# 10

# %%
oc34
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-403fc5bedc02> in <module>
# ----> 1 oc34
#
# NameError: name 'oc34' is not defined

# %%
0c34
# Out:
#   File "<ipython-input-19-7c0103555f62>", line 1
#     0c34
#      ^
# SyntaxError: invalid syntax

# %%
a=5
b=8
b/a
# Out:
# 1.6

# %%
a*1.0
# Out:
# 5.0

# %%
int(3.0)
# Out:
# 3

# %%
0o34
# Out:
# 28

# %%
0xj
# Out:
#   File "<ipython-input-24-c19fdb4a3bab>", line 1
#     0xj
#      ^
# SyntaxError: invalid hexadecimal literal

# %%
import cmath
c1=complex(3,5)
c1.real
# Out:
# 3.0

# %%
c1.imge
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-26-53f7ea922b2a> in <module>
# ----> 1 c1.imge
#
# AttributeError: 'complex' object has no attribute 'imge'

# %%
import cmath
c1=complex(3,5)
c1.imge
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-27-22c697126b03> in <module>
#       1 import cmath
#       2 c1=complex(3,5)
# ----> 3 c1.imge
#
# AttributeError: 'complex' object has no attribute 'imge'

# %%
import cmath
c1=complex(3,5)
c1.imag
# Out:
# 5.0

# %%
k=10
print("{0:x}".format(k))
# Out:
# a

# %% [markdown]
# ### Python object

# %% [markdown]
# a=300
# b=300
# id(a)

# %%
id(a)
# Out:
# 140705940318112

# %%
id(b)
# Out:
# 140705940318208

# %%
type(a)
# Out:
# int

# %%
type(b)
# Out:
# int

# %%
a
# Out:
# 5

# %%
b
# Out:
# 8

# %%
a=300

# %%
b=300
